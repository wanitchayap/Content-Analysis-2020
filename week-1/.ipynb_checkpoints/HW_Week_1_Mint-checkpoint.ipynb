# %% [markdown]
# # Week 1 - Counting Words & Phrases

# %%
#Special module written for this class
#This provides access to data and to helper functions from previous weeks
import lucem_illud_2020 #pip install git+git://github.com/Computational-Content-Analysis-2020/lucem_illud_2020.git

#All these packages need to be installed from pip
import requests #for http requests
import pandas #gives us DataFrames
import matplotlib.pyplot as plt #For graphics
import wordcloud #Makes word clouds
import numpy as np #For divergences/distances
import scipy #For divergences/distances
import seaborn as sns #makes our plots look nicer
import sklearn.manifold #For a manifold plot
import json #For API responses
import urllib.parse #For joining urls

# comp-linguistics
import spacy

#Displays the graphs
import graphviz #You also need to install the command line graphviz

#These are from the standard library
import os.path
import zipfile
import subprocess
import io
import tempfile

#This 'magic' command makes the plots work better
#in the notebook, don't use it outside of a notebook
# %matplotlib inline

# %%
nlp = spacy.load("en")

# %%
def word_tokenize(word_list):
    tokenized = []
    # pass word list through language model.
    doc = nlp(word_list)
    for token in doc:
        if not token.is_punct and len(token.text.strip()) > 0:
            tokenized.append(token.text)
    return tokenized

# %% [markdown]
# I am going to investigate ~3,500 Canadian news articles about COVID-19 available on kaggle.com. The published dates range from the end of December 2019 to the end of March 2020.

# %%
# Corpus from https://www.kaggle.com/ryanxjhan/cbc-news-coronavirus-articles-march-26
covid_news = pandas.read_csv("news.csv")

# Extract date
covid_news['year'] = covid_news['publish_date'].apply(lambda x: int(x[0:4]))
covid_news['mon'] = covid_news['publish_date'].apply(lambda x: int(x[5:7]))
covid_news['day'] = covid_news['publish_date'].apply(lambda x: int(x[8:10]))

# Small number of news are about SARS and MERS
covid_news = covid_news[covid_news['year'] > 2018]

# Sort news from the oldest to the most recent
covid_news.sort_values(['year', 'mon', 'day'], inplace = True)

# Select important columns
covid_news = covid_news[['year', 'mon', 'day', 'authors', 'title', 'description','text']]

# %%
covid_news
# Out:
#       year  mon  day                                            authors  \
# 891   2019   12   22                                       ['Cbc News']
# 3533  2020    1    8                           ['The Associated Press']
# 3378  2020    1    9                                ['Thomson Reuters']
# 3400  2020    1    9                                ['Thomson Reuters']
# 879   2020    1   11                           ['The Associated Press']
# ...    ...  ...  ...                                                ...
# 278   2020    3   27                                                 []
# 281   2020    3   27                                       ['Cbc News']
# 308   2020    3   27                                       ['Cbc News']
# 456   2020    3   27                                                 []
# 661   2020    3   27  ['City Hall Reporter', 'Lauren Pelley Is A Cbc...
#
#                                                   title  \
# 891   Sunday Scrum: Repatriating Canadians from Chin...
# 3533  South Korea reports 1st possible case of viral...
# 3378  Previously unknown virus may be causing pneumo...
# 3400  Previously unknown virus may be causing pneumo...
# 879   China reports 1st death from 'new type of coro...
# ...                                                 ...
# 278   City of Regina laying off 360 casual staff, no...
# 281   Vancouver police report recent spike in commer...
# 308   10 public health workers in the Eastern Townsh...
# 456   WATCH: Portraits at a safe social distance rai...
# 661   Ontario clinicians bracing for 'surge' of COVI...
#
#                                             description  \
# 891   CBC News Network's Sunday Scrum panel is your ...
# 3533  South Korea has put a 36-year-old Chinese woma...
# 3378  A preliminary investigation has now identified...
# 3400  A preliminary investigation has now identified...
# 879   Health authorities in the central Chinese city...
# ...                                                 ...
# 278   The City of Regina says staff will be reduced ...
# 281   Vancouver police say there’s been an increase ...
# 308   Public health authorities in the Eastern Towns...
# 456   Collecting donations for Winnipeg Harvest inst...
# 661   Front-line healthcare workers are bracing for ...
#
#                                                    text
# 891   CBC News Network's Sunday Scrum panel is your ...
# 3533  South Korea has put a 36-year-old Chinese woma...
# 3378  A cluster of more than 50 pneumonia cases in C...
# 3400  A cluster of more than 50 pneumonia cases in C...
# 879   Health authorities in a central Chinese city o...
# ...                                                 ...
# 278   The City of Regina has issued layoff notices t...
# 281   Vancouver police say there's been an increase ...
# 308   Ten public health employees in the Eastern Tow...
# 456   Photographers around the world, including here...
# 661   Front-line healthcare workers are bracing for ...
#
# [3535 rows x 7 columns]

# %% [markdown]
# # Counting words

# %%
def wordCounter(wordLst):
    wordCounts = {}
    for word in wordLst:
        #We usually need to normalize the case
        wLower = word.lower()
        if wLower in wordCounts:
            wordCounts[wLower] += 1
        else:
            wordCounts[wLower] = 1
    #convert to DataFrame
    countsForFrame = {'word' : [], 'count' : []}
    for w, c in wordCounts.items():
        countsForFrame['word'].append(w)
        countsForFrame['count'].append(c)
    return pandas.DataFrame(countsForFrame)

# %%
import nltk

# %% [markdown]
# ## <span style="color:red">*Exercise 1*</span>
#
# <span style="color:red">Construct cells immediately below this that input and interrogate a corpus relating to your anticipated final project. This could include one of the Davies corpora or some other you have constructed. Turn your text into an nltk `Text` object, and explore all of the features examined above, and others that relate to better understanding your corpus in relation to your research question. </span>

# %%
# tokenize news text
covid_news['tokenized_text'] = covid_news['text'].apply(word_tokenize)

# %%
# drop any possible NA
covid_news.dropna(inplace=True)

# %%
# combine all text tokens from all news
covid_token = [element for list_ in covid_news['tokenized_text'].values for element in list_ \
              if not element.startswith(("@","&","\'","<","=",">"))]

# %%
# most frequent tokens
countedWords = wordCounter(covid_token)
countedWords.sort_values('count', ascending=False, inplace=True)
countedWords[:20]
# Out:
#        word   count
# 15      the  133762
# 30       to   85387
# 14       of   61342
# 12      and   59275
# 37       in   53618
# 54        a   47357
# 157    said   30240
# 9       for   27335
# 6        is   26192
# 181    that   25940
# 141      on   23674
# 347     are   21962
# 319      it   18214
# 263    have   17373
# 83     with   16735
# 65       be   16202
# 270      at   15773
# 22       we   15491
# 333  health   15209
# 87       as   15175

# %% [markdown]
# Before normalization, most frequent tokens are not very significant or meaningful.

# %%
# Zipf's law
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(range(len(countedWords)), countedWords['count'])
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_title("Zipf's Law on COVID-19 News Corpus")
ax.set_xlabel("Log Position")
ax.set_ylabel("Log Frequency")
plt.show()

# %% [markdown]
# The frequencies follow the Zipf's law well!

# %%
# counts of interesting tokens
countedWords.loc[countedWords['word'].isin(['covid-19', 'coronavirus', 'death', 'china', 'pandemic'])]
# Out:
#              word  count
# 1660     covid-19  14320
# 34    coronavirus   9158
# 38          china   4051
# 3072     pandemic   3379
# 53          death   1131

# %%
# turn all tokens into NLTK Text and ConcordanceIndex objects
covidText = nltk.Text(covid_token)
covidIndex = nltk.text.ConcordanceIndex(covidText)

# %%
covidIndex.print_concordance('COVID-19')
# Out:
# Displaying 25 of 14283 matches:
#  measures against the spread of the COVID-19 in Vatican City Italy Elisabetta A.
# tory Syndrome SARS CoV Canada first COVID-19 death is not cause for panic but sh
# tial symptoms of the illness called COVID-19 are mainly fever and cough with a f
# ld Canadians do Major problems with COVID-19 outbreaks have occurred on cruise s
# avoid all cruise ship travel due to COVID-19 Tam said The risk to the general po
# orld 6:57 6 What we do n't know yet COVID-19 has created alarm because there are
# d in December CBC ExplainsDo I have COVID-19 the flu or a cold?'Just incredible
# k remains low CBC ExplainsDo I have COVID-19 the flu or a cold About five or six
# virus spreads CBC ExplainsDo I have COVID-19 the flu or a cold He adds if there
# orted in ChinaCBC ExplainsDo I have COVID-19 the flu or a cold One of the patien
#  like illness CBC ExplainsDo I have COVID-19 the flu or a cold?Coronavirus death
# om on Dec. 23 CBC ExplainsDo I have COVID-19 the flu or a cold?Follow the spread
# ealth officials believe the rate of COVID-19 cases in Canada is going to get wor
# fortunately the initial symptoms of COVID-19 are very similar to the seasonal fl
#  know whether you are infected with COVID-19 The symptoms can include Fever Coug
# ould be a primary complaint of some COVID-19 patients But a small study publishe
#  gathered data on 204 patients with COVID-19 in three hospitals in Hubei provinc
#  to the list of screening tools for COVID-19 in the absence of other respiratory
# s Not everyone who is infected with COVID-19 has symptoms and some people will o
# ld CBC News The only way to confirm COVID-19 is with a lab test Symptoms may app
# accine will not protect you against COVID-19 Here the World Health Organization
# shortness of breath The symptoms of COVID-19 are similar to those of the seasona
# est risk for developing more severe COVID-19 disease include those Aged 65 and o
# nderlying medical conditions How is COVID-19 diagnosed Respiratory samples are p
# n of the coronavirus What if I have COVID-19 but get sent home Public health off

# %%
covidIndex.print_concordance('death')
# Out:
# Displaying 25 of 1099 matches:
# ership race We also discuss what the death of a sex worker says about the curre
# e Derek Sloan 10:31 WATCH Sex worker death prompts joint investigation The deat
# eath prompts joint investigation The death of 22-year old Marylène Levesque is
#  outbreak for weeks before a growing death toll and rumors forced the governmen
#  outbreak for weeks before a growing death toll and rumors forced the governmen
#  Saturday reported the country first death from a new type of coronavirus as th
# us related to SARS?China reports 1st death from new type of coronavirus Among 4
# cases of the infection including one death have been identified in Wuhan City C
#  in China WHO says China reports 1st death from new type of coronavirus The app
# cases of the infection including one death have been identified in Wuhan City C
#  in China WHO says China reports 1st death from new type of coronavirus The app
# ld man had died in China first known death from the virus The Wuhan Municipal H
# Health Commission announced a second death a 69-year old man on Thursday He bec
# ld man had died in China first known death from the virus The Wuhan Municipal H
# Health Commission announced a second death a 69-year old man on Thursday He bec
# s spread to more cities with a third death reported and the total number of peo
# ave no further details of the latest death toll What are public health official
# drome SARS CoV Canada first COVID-19 death is not cause for panic but shows nee
# ory syndrome kidney failure and even death The only way to confirm infection is
# lth Commission Wednesday morning The death toll from the outbreak has risen to
# lth authority said on Tuesday As the death toll from the mysterious flu like vi
# aimed Britain King one day after the death of his father King George V. Edward
# Thatcher is found beaten and shot to death in the garage of her Regina home Tha
# id Milgaard murder conviction in the death of Saskatoon nursing aide Gail Mille
#  girls to enter Eskasoni pageant The death toll from China new respiratory viru

# %%
# random 20 collocations occur in the news
covidText.collocation_list()
# Out:
# ['per cent',
#  'public health',
#  'social distancing',
#  'Nova Scotia',
#  'CBC News',
#  'self isolate',
#  'health care',
#  'tested positive',
#  'Public Health',
#  'novel coronavirus',
#  'confirmed cases',
#  'self isolation',
#  'cruise ship',
#  'federal government',
#  'health officials',
#  'medical officer',
#  'Prime Minister',
#  'New Brunswick',
#  'hand sanitizer',
#  'non essential']

# %% [markdown]
# Most bigram collocations are compound nouns related to health.

# %%
# 20 tokens most similar to 'China'
covidText.similar('China')
# Out:
# the canada it and wuhan that people ontario italy ottawa coronavirus a
# toronto alberta this iran manitoba quebec march cases

# %% [markdown]
# We can see similar words to China are mostly Geopolitical entities related to Canada or related to COVID-19

# %%
covidText.similar('COVID')
# Out:
# coronavirus health them people us the china canadians that sars
# symptoms all canada virus global travel emergency help and what

# %% [markdown]
# Many words related to COVID are actually viral diseases: SARS, H1N1, Ebola.

# %%
sns.reset_orig()
# Word Offset corespond to news' published timeline
covidText.dispersion_plot(['Coronavirus', 'COVID-19', 'SARS', 'death', 'quarantine', 'distancing', 'vaccine'])
# Out:
# /Users/wanitchaya.poon/opt/anaconda3/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The examples.directory rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2. In the future, examples will be found relative to the 'datapath' directory.
#   self[key] = other[key]
# /Users/wanitchaya.poon/opt/anaconda3/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/wanitchaya.poon/opt/anaconda3/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The text.latex.unicode rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2.
#   self[key] = other[key]
# /Users/wanitchaya.poon/opt/anaconda3/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/wanitchaya.poon/opt/anaconda3/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]

# %% [markdown]
# Since I sorted the news by their published date in ascending order, the word offset coresponds to the news' published timeline. This plot is quite informative. We can see 'Coronavirus' was used more in the begining and gradually faded away, replaced by 'COVID-19'. We can also roughly infer when the concept of 'Social Distancing' started to be commonly used from the word 'distancing'. 'SARS' was used a lot at the beginning of the outbreak timeline, but it was dropped quite rapidly, signalling that COVID-19 itself became a familiar word.

# %%
covidText.dispersion_plot(['Wuhan', 'China', 'Korean', 'Cruise', 'Iran', 'Italy', 'U.S.', 'Canada'])
sns.set()

# %% [markdown]
# Similar to the first dispersion plot, this plot plotting names of related countries is quite informative. Wuhan appeared a lot in the begining but faded away rapidly. Korean was only mentioned frequently in a short period while Italy was mentioned a lot in a long period of time.

# %%
# generating 100-word text from current corpus
covidText.generate()
# Out:
# Building ngram index...
# on COVID-19 This includes teachers students and chaperones heard from
# are feeling a great place to ensure that those aboard the cruise line
# and we feel are inadequate in prisons given the nature of the
# manufacturing power of the most reported cases That becomes a bigger
# change for the first four cases in the next regularly scheduled
# programming You can walk your dog mouth is the crowd at the RCMP are
# following up on the floor that are desperately looking for common
# sense right now Or start taking the COVID-19 crisis according to a
# Saturday night with performances of traditional
# 'on COVID-19 This includes teachers students and chaperones heard from\nare feeling a great place to ensure that those aboard the cruise line\nand we feel are inadequate in prisons given the nature of the\nmanufacturing power of the most reported cases That becomes a bigger\nchange for the first four cases in the next regularly scheduled\nprogramming You can walk your dog mouth is the crowd at the RCMP are\nfollowing up on the floor that are desperately looking for common\nsense right now Or start taking the COVID-19 crisis according to a\nSaturday night with performances of traditional'

# %% [markdown]
# ### News articles published before March

# %%
# combine all text tokens from news before march
covid_token = [element for list_ in covid_news[covid_news['mon'] != 3]['tokenized_text'].values for element in list_ \
              if not element.startswith(("@","&","\'","<","=",">"))]

# %%
# counts of interesting tokens
countedWords = wordCounter(covid_token)
countedWords.loc[countedWords['word'].isin(['covid-19', 'coronavirus', 'death', 'china', 'pandemic'])]
# Out:
#              word  count
# 34    coronavirus   3549
# 38          china   3024
# 53          death    298
# 1660     covid-19    589
# 3072     pandemic    203

# %% [markdown]
# We can see that Coronavirus were more common word than COVID-19 before March, and the news still mentioned China a lot.

# %%
# turn all tokens into NLTK Text and ConcordanceIndex objects
covidText = nltk.Text(covid_token)
covidText.generate()
# Out:
# Building ngram index...
# of Asia Milan at a news release Assembly of Manitoba Great Wall
# Performing Arts which was developed in wake of the passengers and crew
# to 174 Who the Canadian government to increase rapidly as the
# government to help them navigate that Cellphones transform Kenyan
# commerce Lester said the passengers are coping 5:19 It critical to
# make any historical or epidemiological sense Facts vs. fear Experts
# offer advice on how long it would remove accounts engaging in those
# kinds of groups in a round table discussion with the logistical side
# of caution in northern British Columbia according to last year the
# 'of Asia Milan at a news release Assembly of Manitoba Great Wall\nPerforming Arts which was developed in wake of the passengers and crew\nto 174 Who the Canadian government to increase rapidly as the\ngovernment to help them navigate that Cellphones transform Kenyan\ncommerce Lester said the passengers are coping 5:19 It critical to\nmake any historical or epidemiological sense Facts vs. fear Experts\noffer advice on how long it would remove accounts engaging in those\nkinds of groups in a round table discussion with the logistical side\nof caution in northern British Columbia according to last year the'

# %% [markdown]
# The text generated from the corpus before March doesn't really clearly signal there was a pandemic going on globally...

# %% [markdown]
# ### News articles published in March

# %%
# combine all text tokens from news before march
covid_token = [element for list_ in covid_news[covid_news['mon'] == 3]['tokenized_text'].values for element in list_ \
              if not element.startswith(("@","&","\'","<","=",">"))]

# %%
# counts of interesting tokens
countedWords = wordCounter(covid_token)
countedWords.loc[countedWords['word'].isin(['covid-19', 'coronavirus', 'death', 'china', 'pandemic'])]
# Out:
#             word  count
# 19      covid-19  13731
# 38   coronavirus   5609
# 369        china   1027
# 464        death    833
# 650     pandemic   3176

# %% [markdown]
# COVID-19 became a popular word!

# %%
# turn all tokens into NLTK Text and ConcordanceIndex objects
covidText = nltk.Text(covid_token)
covidText.generate()
# Out:
# Building ngram index...
# on COVID-19 This includes staying home when possible and all domestic
# flights On Friday morning including a paper titled Coronaphobia Fear
# and the Peruvian government has also banned travel in response to the
# virus and not the right to refuse work amid COVID-19 concerns COVID-19
# Here are some of the country after March break for most of them are
# getting very little income for weeks or months 20:29 Trudeau also
# confirmed to have been paid by the end of May. But that cuts both ways
# they can in an email late last week or so Saghbini had to get all
# 'on COVID-19 This includes staying home when possible and all domestic\nflights On Friday morning including a paper titled Coronaphobia Fear\nand the Peruvian government has also banned travel in response to the\nvirus and not the right to refuse work amid COVID-19 concerns COVID-19\nHere are some of the country after March break for most of them are\ngetting very little income for weeks or months 20:29 Trudeau also\nconfirmed to have been paid by the end of May. But that cuts both ways\nthey can in an email late last week or so Saghbini had to get all'

# %% [markdown]
# Now you can see COVID-19 was awared as a global pandemic!!!

# %% [markdown]
# # Filtering and normalizing text

# %%
def normalizeTokens(word_list, extra_stop=[]):
    #We can use a generator here as we just need to iterate over it
    normalized = []
    if type(word_list) == list and len(word_list) == 1:
        word_list = word_list[0]

    if type(word_list) == list:
        word_list = ' '.join([str(elem) for elem in word_list]) 

    doc = nlp(word_list.lower())
    
    # add the property of stop word to words considered as stop words
    if len(extra_stop) > 0:
        for stopword in extra_stop:
            lexeme = nlp.vocab[stopword]
            lexeme.is_stop = True

    for w in doc:
        # if it's not a stop word or punctuation mark, add it to our article
        if w.text != '\n' and not w.is_stop and not w.is_punct and not w.like_num and len(w.text.strip()) > 0:
            # we add the lematized version of the word
            normalized.append(str(w.lemma_))

    return normalized

# %%
def spacy_pos(word_list):
    tags = []
    doc = nlp(word_list.lower())
    for w in doc:
        tags.append((w.text, w.tag_))
    return tags

# %% [markdown]
# ## <span style="color:red">*Exercise 2*</span>
#
# <span style="color:red">Construct cells immediately below this that filter, stem and lemmatize the tokens in your corpus, and then creates plots (with titles and labels) that map the word frequency distribution, word probability distribution, and at least two conditional probability distributions that help us better understand the social and cultural game underlying the production of your corpus. Create a wordl of words (or normalized words) and add a few vague comments about what mysteries are revealed through it.</span>

# %%
countsDict = {}
for word in covid_token:
    if word in countsDict:
        countsDict[word] += 1
    else:
        countsDict[word] = 1
word_counts = sorted(countsDict.items(), key = lambda x : x[1], reverse = True)
word_counts[:20]
# Out:
# [('the', 93115),
#  ('to', 71179),
#  ('of', 49631),
#  ('and', 48361),
#  ('in', 39553),
#  ('a', 35957),
#  ('said', 25065),
#  ('for', 22234),
#  ('is', 21617),
#  ('that', 20067),
#  ('are', 18705),
#  ('on', 17865),
#  ('have', 14159),
#  ('The', 13983),
#  ('COVID-19', 13698),
#  ('be', 13572),
#  ('with', 13256),
#  ('at', 12313),
#  ('as', 11248),
#  ('it', 11133)]

# %% [markdown]
# I am going to set 'COVID-19' as the cut-off

# %%
#The stop list is then all words that occur before the first noun
stop_words_freq = []
for word, count in word_counts:
    if word == 'COVID-19':
        break
    else:
        stop_words_freq.append(word)
stop_words_freq
# Out:
# ['the',
#  'to',
#  'of',
#  'and',
#  'in',
#  'a',
#  'said',
#  'for',
#  'is',
#  'that',
#  'are',
#  'on',
#  'have',
#  'The']

# %%
# Normalizing and doing POS tag
covid_news['normalized_tokens'] = covid_news['tokenized_text'].apply(lambda x: normalizeTokens(x))
covid_news['normalized_tokens_count'] = covid_news['normalized_tokens'].apply(lambda x: len(x))
covid_news['normalized_tokens_POS'] = [spacy_pos(t) for t in covid_news['text']]

# %%
# Conditional Frequency and Probability on POS
covidcfdist_POStoWord = nltk.ConditionalFreqDist((p, w) for w, p in covid_news['normalized_tokens_POS'].sum())
covidcpdist_POStoWord = nltk.ConditionalProbDist(covidcfdist_POStoWord, nltk.ELEProbDist)

# %%
print("\t Top 10 Conditional Frequency Distribution on Noun")
covidcfdist_POStoWord['NN'].plot(10);
# Out:
# 	 Top 10 Conditional Frequency Distribution on Noun

# %%
covidcpdist_POStoWord['NN'].max()
# Out:
# 'health'

# %%
covidcpdist_POStoWord['NN'].prob(covidcpdist_POStoWord['NN'].max())
# Out:
# 0.0273034520602614

# %% [markdown]
# 'health' is the most likely noun. Not that surprising since pandemic is all about health.

# %%
print("\t Top 10 Conditional Frequency Distribution on Adjective")
covidcfdist_POStoWord['JJ'].plot(10);
# Out:
# 	 Top 10 Conditional Frequency Distribution on Adjective

# %%
covidcpdist_POStoWord['JJ'].max()
# Out:
# 'public'

# %%
covidcpdist_POStoWord['JJ'].prob(covidcpdist_POStoWord['JJ'].max())
# Out:
# 0.03176386240207134

# %% [markdown]
# 'public' is the most likely adjective, reflecting the nature of the pandemic well.

# %%
print("\t Top 10 Conditional Frequency Distribution on Past Tense Verb")
covidcfdist_POStoWord['VBN'].plot(10);
# Out:
# 	 Top 10 Conditional Frequency Distribution on Past Tense Verb

# %% [markdown]
# 'been' is not that informative. However, 'confirmed' and 'tested' are relevant to diagnosing COVID-19. 'cancelled' and 'closed' probably refer to all activity being shut down from COVID-19.

# %%
covidcpdist_POStoWord['VBN'].max()
# Out:
# 'been'

# %%
covidcpdist_POStoWord['VBN'].prob(covidcpdist_POStoWord['VBN'].max())
# Out:
# 0.11219470153013869

# %%
# add a column for future use
covid_news['md'] =  covid_news['year'].apply(str) + "-" + covid_news['mon'].apply(str) + "-" + covid_news['day'].apply(str)

# %%
wc = wordcloud.WordCloud(background_color="white", max_words=500, width= 2500, height = 00, 
                         mode ='RGBA', scale=.5).generate(' '.join(covid_news['normalized_tokens'].sum()))
plt.imshow(wc)
plt.axis("off")
# Out:
# (-0.5, 1249.5, 1249.5, -0.5)

# %% [markdown]
# This suggests that the news mostly talked about 1) health care related words, 2) where (locations, community, china), 3) and what actions (work, spread, social distancing).
#
# ### Articles before March

# %%
wc = wordcloud.WordCloud(background_color="white", max_words=500, width= 2500, height = 2500, 
                         mode ='RGBA', scale=.5).generate(' '.join(covid_news[covid_news['mon'] != 3]['normalized_tokens'].sum()))
plt.imshow(wc)
plt.axis("off")
#plt.savefig("janfeb.png", format = 'png')

# %% [markdown]
# Before March, the news heavily talked about China. Doesn't seem to view COVID-19 as a global issue yet.
#
# ### Article in March

# %%
wc = wordcloud.WordCloud(background_color="white", max_words=500, width= 2500, height = 2500, 
                         mode ='RGBA', scale=.5).generate(' '.join(covid_news[covid_news['mon'] == 3]['normalized_tokens'].sum()))
plt.imshow(wc)
plt.axis("off")
#plt.savefig("mar.png", format = 'png')

# %% [markdown]
# However, in March, the work China did not dominate the news and now COVID-19 seems to recognized as global issue.

# %%
import pandas as pd

# %% [markdown]
# # Part-of-Speech (POS) tagging

# %%
def sent_tokenize(word_list):
    doc = nlp(word_list)
    sentences = [sent.string.strip() for sent in doc.sents]
    return sentences

# %%
def tag_sents_pos(sentences):
    """
    function which replicates NLTK pos tagging on sentences.
    """
    new_sents = []
    for sentence in sentences:
        new_sent = ' '.join(sentence)
        new_sents.append(new_sent)
    final_string = ' '.join(new_sents)
    doc = nlp(final_string)
    
    pos_sents = []
    for sent in doc.sents:
        pos_sent = []
        for token in sent:
            pos_sent.append((token.text, token.tag_))
        pos_sents.append(pos_sent)
    
    return pos_sents

# %% [markdown]
# ## <span style="color:red">*Your turn*</span>
#
# <span style="color:red">In the cells immediately following, perform POS tagging on a meaningful (but modest) subset of a corpus associated with your final project. Examine the list of words associated with at least three different parts of speech. Consider conditional associations (e.g., adjectives associated with nouns or adverbs with verbs of interest). What do these distributions suggest about your corpus?

# %%
# create a small corpus consists only the last 50 articles
covid_small = covid_news[-50:]
covid_small['sentences'] = covid_small['text'].apply(lambda x: [word_tokenize(s) for s in sent_tokenize(x)])
covid_small['POS_sents'] = covid_small['sentences'].apply(lambda x: tag_sents_pos(x))
# Out:
# /Users/wanitchaya.poon/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/wanitchaya.poon/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
covid_small['POS_sents'][:10]
# Out:
# 1209    [[(A, DT), (Sudbury, NNP), (couple, NN), (that...
# 1220    [[(As, IN), (politicians, NNS), (and, CC), (pu...
# 1221    [[(A, DT), (group, NN), (that, WDT), (advocate...
# 1223    [[(THE, DT), (LATEST, NNP), (People, NNS), (wh...
# 1239    [[(As, IN), (politicians, NNS), (and, CC), (pu...
# 1273    [[(Closed, NNP), (concert, NN), (halls, NNS), ...
# 1283    [[(An, DT), (inmate, NN), (was, VBD), (admitte...
# 1352    [[(When, WRB), (it, PRP), (comes, VBZ), (to, I...
# 0       [[(Canadian, JJ), (pharmacies, NNS), (are, VBP...
# 1       [[(The, DT), (Yukon, NNP), (government, NN), (...
# Name: POS_sents, dtype: object

# %% [markdown]
# ### Nouns and Associated Adjectives

# %%
countTarget = 'NN'
targetCounts = {}
for entry in covid_small['POS_sents']:
    for sentence in entry:
        for ent, kind in sentence:
            if kind != countTarget:
                continue
            elif ent in targetCounts:
                targetCounts[ent] += 1
            else:
                targetCounts[ent] = 1
sortedTargets = sorted(targetCounts.items(), key = lambda x: x[1], reverse = True)
sortedTargets[:20]
# Out:
# [('health', 139),
#  ('government', 72),
#  ('province', 65),
#  ('emergency', 60),
#  ('care', 58),
#  ('pandemic', 56),
#  ('time', 56),
#  ('COVID-19', 50),
#  ('week', 46),
#  ('spread', 44),
#  ('number', 42),
#  ('cent', 42),
#  ('testing', 41),
#  ('community', 39),
#  ('staff', 39),
#  ('virus', 39),
#  ('home', 38),
#  ('isolation', 37),
#  ('work', 36),
#  ('self', 36)]

# %%
NTarget = 'JJ'
Word = 'isolation'
NResults = set()
for entry in covid_small['POS_sents']:
    for sentence in entry:
        for (ent1, kind1),(ent2,kind2) in zip(sentence[:-1], sentence[1:]):
            if (kind1,ent2.lower())==(NTarget,Word):
                NResults.add(ent1)
            else:
                continue

print(NResults)
# Out:
# {'social', 'medical', 'acute'}

# %% [markdown]
# SOCIAL isolation and MEDICAL isolation are common terms we see in COVID-19 situations. It is interesting how the news use ACUTE to explain isolation. This suggests how the isolation is viewed as very extreme.

# %%
NTarget = 'JJ'
Word = 'pandemic'
NResults = set()
for entry in covid_small['POS_sents']:
    for sentence in entry:
        for (ent1, kind1),(ent2,kind2) in zip(sentence[:-1], sentence[1:]):
            if (kind1,ent2.lower())==(NTarget,Word):
                NResults.add(ent1)
            else:
                continue

print(NResults)
# Out:
# {'COVID-19', 'global', 'current', 'prolonged', 'other', 'deadly', 'unified', 'communitiesIndigenous', 'whole'}

# %% [markdown]
# Adjectives associated to 'pandemic' reflect how serious COVID-19 are now.

# %%
NTarget = 'JJ'
Word = 'work'
NResults = set()
for entry in covid_small['POS_sents']:
    for sentence in entry:
        for (ent1, kind1),(ent2,kind2) in zip(sentence[:-1], sentence[1:]):
            if (kind1,ent2.lower())==(NTarget,Word):
                NResults.add(ent1)
            else:
                continue

print(NResults)
# Out:
# {'online', 'unsafe'}

# %% [markdown]
# ### Verb and Associated Adverb

# %%
countTarget = 'VB'
targetCounts = {}
for entry in covid_small['POS_sents']:
    for sentence in entry:
        for ent, kind in sentence:
            if kind != countTarget:
                continue
            elif ent in targetCounts:
                targetCounts[ent] += 1
            else:
                targetCounts[ent] = 1
sortedTargets = sorted(targetCounts.items(), key = lambda x: x[1], reverse = True)
sortedTargets[:20]
# Out:
# [('be', 220),
#  ('have', 55),
#  ('help', 44),
#  ('do', 36),
#  ('get', 28),
#  ('come', 27),
#  ('take', 25),
#  ('make', 25),
#  ('keep', 25),
#  ('go', 24),
#  ('see', 22),
#  ('ensure', 19),
#  ('continue', 19),
#  ('provide', 18),
#  ('stay', 17),
#  ('reduce', 17),
#  ('isolate', 16),
#  ('use', 15),
#  ('call', 15),
#  ('work', 13)]

# %%
NTarget = 'RB'
Word = 'stay'
NResults = set()
for entry in covid_small['POS_sents']:
    for sentence in entry:
        for (ent1, kind1),(ent2,kind2) in zip(sentence[:-1], sentence[1:]):
            if (kind1,ent2.lower())==(NTarget,Word):
                NResults.add(ent1)
            else:
                continue

print(NResults)
# Out:
# {'seriously'}

# %% [markdown]
# May be a call for people to SERIOUSLY stay home?
#
# ### Adjective and Adverb

# %%
countTarget = 'JJ'
targetCounts = {}
for entry in covid_small['POS_sents']:
    for sentence in entry:
        for ent, kind in sentence:
            if kind != countTarget:
                continue
            elif ent in targetCounts:
                targetCounts[ent] += 1
            else:
                targetCounts[ent] = 1
sortedTargets = sorted(targetCounts.items(), key = lambda x: x[1], reverse = True)
sortedTargets[:20]
# Out:
# [('COVID-19', 155),
#  ('public', 63),
#  ('other', 62),
#  ('new', 47),
#  ('pandemic', 45),
#  ('essential', 41),
#  ('many', 37),
#  ('social', 35),
#  ('federal', 34),
#  ('last', 32),
#  ('positive', 31),
#  ('such', 30),
#  ('medical', 30),
#  ('provincial', 27),
#  ('local', 26),
#  ('safe', 26),
#  ('possible', 22),
#  ('good', 21),
#  ('available', 20),
#  ('different', 18)]

# %%
countTarget = 'RB'
targetCounts = {}
for entry in covid_small['POS_sents']:
    for sentence in entry:
        for ent, kind in sentence:
            if kind != countTarget:
                continue
            elif ent in targetCounts:
                targetCounts[ent] += 1
            else:
                targetCounts[ent] = 1
sortedTargets = sorted(targetCounts.items(), key = lambda x: x[1], reverse = True)
sortedTargets[:20]
# Out:
# [('not', 118),
#  ("n't", 108),
#  ('also', 86),
#  ('now', 70),
#  ('still', 53),
#  ('home', 39),
#  ('well', 39),
#  ('already', 34),
#  ('just', 34),
#  ('only', 32),
#  ('as', 30),
#  ('back', 29),
#  ('very', 27),
#  ('so', 26),
#  ('even', 22),
#  ('right', 20),
#  ('currently', 18),
#  ('too', 16),
#  ('about', 15),
#  ('really', 14)]

# %% [markdown]
# # Collocations

# %% [markdown]
# ## <span style="color:red">*Exercise 3*</span>
#
# <span style="color:red">Construct cells immediately below this that identify statistically significant bigrams, trigrams, quadgrams, higher-order *n*grams and skipgrams. Explore whether these collocations are idiomatic and so irreducible to the semantic sum of their component words. You can do this by examination of conditional frequencies (e.g., what else is 'united' besides the 'United States'). If these phrases are idiomatic, what do they suggest about the culture of the world producing them?

# %% [markdown]
# ### Bigram

# %%
covidBigrams = nltk.collocations.BigramCollocationFinder.from_words(covid_news['normalized_tokens'].sum())
print("There are {} bigrams in the finder".format(covidBigrams.N))
# Out:
# There are 1349843 bigrams in the finder

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
covidBigrams.score_ngrams(bigram_measures.likelihood_ratio)[:10]
# Out:
# [(('public', 'health'), 27052.23702495003),
#  (('social', 'distancing'), 18220.862341704884),
#  (('self', 'isolate'), 15354.617105115958),
#  (('nova', 'scotia'), 14499.976686342889),
#  (('confirm', 'case'), 12602.615422991677),
#  (('test', 'positive'), 12269.555855391205),
#  (('cruise', 'ship'), 11732.10978958306),
#  (('prime', 'minister'), 10524.681847566744),
#  (('cbc', 'news'), 10231.33231005137),
#  (('novel', 'coronavirus'), 9918.667478845373)]

# %% [markdown]
# ### Trigram

# %%
covidTrigrams = nltk.collocations.TrigramCollocationFinder.from_words(covid_news['normalized_tokens'].sum())
print("There are {} trigrams in the finder".format(covidTrigrams.N))
# Out:
# There are 1349843 trigrams in the finder

# %%
trigram_measures = nltk.collocations.TrigramAssocMeasures()
covidTrigrams.score_ngrams(trigram_measures.student_t)[:10]
# Out:
# [(('medical', 'officer', 'health'), 27.746801166454418),
#  (('health', 'care', 'worker'), 25.72449691091411),
#  (('chief', 'medical', 'officer'), 25.159185378288257),
#  (('world', 'health', 'organization'), 24.938907795505038),
#  (('public', 'health', 'official'), 23.866189794004146),
#  (('public', 'health', 'officer'), 22.75385685688032),
#  (('chief', 'public', 'health'), 22.31093552715719),
#  (('=', 'hash&amp;ref_src', '='), 21.236746065488905),
#  (('prime', 'minister', 'justin'), 20.760504576035608),
#  (('minister', 'justin', 'trudeau'), 20.760493193908584)]

# %% [markdown]
# ### 4-gram

# %%
Ngrams = nltk.ngrams(covid_news['normalized_tokens'].sum(), 4)
Counts = {}
for ngram in list(Ngrams):
    if ngram in Counts.keys():
        Counts[ngram] += 1
    else:
        Counts[ngram] = 1

# %%
Filtered = {}
for key in Counts.keys():
    if Counts[key] < 170:
        pass
    else:
        Filtered[key] = Counts[key]
Filtered
# Out:
# {('public', 'health', 'agency', 'canada'): 304,
#  ('canada', 'chief', 'public', 'health'): 176,
#  ('chief', 'public', 'health', 'officer'): 455,
#  ('chief', 'medical', 'officer', 'health'): 437,
#  ('medical', 'officer', 'health', 'dr'): 195,
#  ('prime', 'minister', 'justin', 'trudeau'): 431,
#  ('health', 'officer', 'dr', 'bonnie'): 178,
#  ('officer', 'dr', 'bonnie', 'henry'): 178,
#  ('provincial', 'health', 'officer', 'dr'): 171}

# %% [markdown]
# ### 6-gram

# %%
Ngrams = nltk.ngrams(covid_news['normalized_tokens'].sum(), 6)
Counts = {}
for ngram in list(Ngrams):
    if ngram in Counts.keys():
        Counts[ngram] += 1
    else:
        Counts[ngram] = 1

# %%
Filtered = {}
for key in Counts.keys():
    if Counts[key] < 150:
        pass
    else:
        Filtered[key] = Counts[key]
Filtered
# Out:
# {('provincial', 'health', 'officer', 'dr', 'bonnie', 'henry'): 165}

# %% [markdown]
# ### Skipgram

# %%
skipgrams = nltk.skipgrams(covid_news['normalized_tokens'].sum(), 2, 2)
Counts = {}
for ngram in list(skipgrams):
    if ngram in Counts.keys():
        Counts[ngram] += 1
    else:
        Counts[ngram] = 1

# %%
Filtered = {}
for key in Counts.keys():
    if Counts[key] < 1200:
        pass
    else:
        Filtered[key] = Counts[key]
Filtered
# Out:
# {('cbc', 'news'): 1243,
#  ('health', 'say'): 1955,
#  ('new', 'case'): 1363,
#  ('say', 'people'): 1614,
#  ('public', 'health'): 3964,
#  ('health', 'official'): 1710,
#  ('health', 'care'): 1805,
#  ('confirm', 'case'): 2456,
#  ('test', 'positive'): 1325,
#  ('chief', 'officer'): 1314,
#  ('stay', 'home'): 1212,
#  ('self', 'isolate'): 1429,
#  ('case', 'covid-19'): 1535,
#  ('social', 'distancing'): 1472}

# %% [markdown]
# <span style="color:red">**Stretch**: In Manning and Schütze's textbook, there Section 5.3.2 explores how to use the *t*-test to find words whose co-occurance patterns best distinguish two words. Implement that and use it to explore phrases in your corpus. For instance, you could tell what words come after "America" much more often than after "Iraq"?</span>

# %%
bigrams = list(nltk.ngrams(covid_news['normalized_tokens'].sum(), 2))

# %%
health_x = [i[1] for i in bigrams if i[0] == 'health']
medical_x = [i[1] for i in bigrams if i[0] == 'medical']

# %%
count_health = wordCounter(health_x).rename(columns={"word": "word", "count": "health"})
count_medical = wordCounter(medical_x).rename(columns={"word": "word", "count": "medical"})

# %%
t_test = pd.merge(count_health, count_medical, on='word', how='outer')
t_test.fillna(0, inplace=True)
t_test['t'] = abs(t_test['health'] - t_test['medical'])/((t_test['health'] + t_test['medical'])**0.5)

# %% [markdown]
# Below are top 10 words distinguish 'health' from 'medical' the most. In general, 'health' is used as adjective more than 'medical'.

# %%
t_test.sort_values('t', ascending = False)[:10]
# Out:
#             word  health  medical          t
# 9           care  1762.0     73.0  39.428623
# 6       official  1600.0     33.0  38.777152
# 0      authority   821.0      3.0  28.496380
# 11      minister   658.0      0.0  25.651511
# 1   organization   643.0      1.0  25.298344
# 15           say   430.0      2.0  20.592160
# 39          unit   406.0      1.0  20.075105
# 2         agency   401.0      0.0  20.024984
# 23     emergency   442.0     20.0  19.633217
# 71        safety   284.0      0.0  16.852300

# %% [markdown]
# Below are words that used with 'medical' more and distinguish 'health' from 'medical' the most.

# %%
t_test[t_test['medical'] > t_test['health']].sort_values('t', ascending = False)[:10]
# Out:
#              word  health  medical          t
# 797        supply     3.0    163.0  12.418408
# 564     equipment     3.0     93.0   9.185587
# 97         health    21.0    105.0   7.483315
# 988          mask     0.0     51.0   7.141428
# 244         staff    20.0     88.0   6.543303
# 985     attention     0.0     41.0   6.403124
# 998   contributor     0.0     34.0   5.830952
# 796   appointment     1.0     28.0   5.013774
# 1011       device     0.0     19.0   4.358899
# 569   association    14.0     46.0   4.131182

# %% [markdown]
# # Named-Entity Recognition

# %%
def tag_sents_ner(sentences):
    """
    function which replicates NLTK ner tagging on sentences.
    """
    new_sents = []
    for sentence in sentences:
        new_sent = ' '.join(sentence)
        new_sents.append(new_sent)
    final_string = ' '.join(new_sents)
    doc = nlp(final_string)
    
    pos_sents = []
    for sent in doc.sents:
        pos_sent = []
        for ent in sent.ents:
            pos_sent.append((ent.text, ent.label_))
        pos_sents.append(pos_sent)
    
    return pos_sents

# %% [markdown]
# ## <span style="color:red">*Exercise 4*</span>
#
# <span style="color:red">In the cells immediately following, perform NER on a (modest) subset of your corpus of interest. List all of the different kinds of entities tagged? What does their distribution suggest about the focus of your corpus? For a subset of your corpus, tally at least one type of named entity and calculate the Precision, Recall and F-score for the NER classification just performed.

# %%
covid_small['classified_sents'] = covid_small['sentences'].apply(lambda x: tag_sents_ner(x))
# Out:
# /Users/wanitchaya.poon/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
NERCounts = {}
for entry in covid_small['classified_sents']:
    for sentence in entry:
        for ent, kind in sentence:
            if kind in NERCounts:
                NERCounts[kind] += 1
            else:
                NERCounts[kind] = 1
sortedNER = sorted(NERCounts.items(), key = lambda x: x[1], reverse = True)
df = pandas.DataFrame(sortedNER)
df.rename(columns={0: "NER", 1: "Count"}, inplace = True)
p = sns.barplot(df['Count'], df['NER'])
p.set_title("Name Entity Counts by Type in the Latest 100 CBC COVID-19 News");

# %% [markdown]
# Organization is the top type of NER in the corpus, followed by person and Geopolitical entity.

# %%
GPECounts = {}
for entry in covid_small['classified_sents']:
    for sentence in entry:
        for ent, kind in sentence:
            if kind == 'GPE':
                if ent in GPECounts:
                    GPECounts[ent] += 1
                else:
                    GPECounts[ent] = 1
sortedGPE = sorted(GPECounts.items(), key = lambda x: x[1], reverse = True)
df = pandas.DataFrame(sortedGPE[:20])
df.rename(columns={0: "GPE", 1: "Count"}, inplace = True)
p = sns.barplot(df['Count'], df['GPE'])
p.set_title("Top 20 Geopolitical Entities in the Latest 100 CBC COVID-19 News");

# %% [markdown]
# Not surprising, Canada-related GPEs dominated the corpus. Interestingly, Peru was mentioned more than Italy...?

# %%
NORPCounts = {}
for entry in covid_small['classified_sents']:
    for sentence in entry:
        for ent, kind in sentence:
            if kind == 'NORP':
                if ent in NORPCounts:
                    NORPCounts[ent] += 1
                else:
                    NORPCounts[ent] = 1
sortedNORP = sorted(NORPCounts.items(), key = lambda x: x[1], reverse = True)
df = pandas.DataFrame(sortedNORP[:20])
df.rename(columns={0: "NORP", 1: "Count"}, inplace = True)
p = sns.barplot(df['Count'], df['NORP'])
p.set_title("Top 20 Nationalities or religious or political groups in the Latest 100 CBC COVID-19 News");

# %% [markdown]
# # Dependency parsing and graph representations

# %%
from spacy import displacy
from spacy.symbols import nsubj, VERB

# %% [markdown]
# ## <span style="color:red">*Your turn*</span>
#
# <span style="color:red">In the cells immediately following, parse a (modest) subset of your corpus of interest. How deep are the phrase structure and dependency parse trees nested? How does parse depth relate to perceived sentence complexity? What are five things you can extract from these parses for subsequent analysis? (e.g., nouns collocated in a noun phrase; adjectives that modify a noun; etc.) Capture these sets of things for a focal set of words (e.g., "Bush", "Obama", "Trump"). What do they reveal about the roles that these entities are perceive to play in the social world inscribed by your texts?

# %%
print(" ".join(covid_small['sentences'][0][0]))
doc = nlp(" ".join(covid_small['sentences'][0][0]))
displacy.render(doc, style='dep')
# Out:
# Canadian pharmacies are limiting how much medication can be dispensed to try to prevent shortages recognizing that most active ingredients for drugs come from India and China and medical supply chains have been disrupted by the spread of COVID-19
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="9d2ea801016b4683a19e7c383ffcd8be-0" class="displacy" width="6875" height="749.5" direction="ltr" style="max-width: none; height: 749.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Canadian</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">pharmacies</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">limiting</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">how</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">much</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">medication</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">dispensed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">try</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">prevent</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">shortages</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">recognizing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">most</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">active</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">ingredients</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">drugs</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">come</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">India</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">China</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">medical</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">supply</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">chains</tspan>
#     <tspan class="displacy-tag" dy=

# %% [markdown]
# Since this sentence is extremely long (and it consists of many sub-sentences), it is not surprising to see a very complex dependency graph!

# %%
# nouns and what they are dependent on
for chunk in doc.noun_chunks:
    print(chunk.text, "-", chunk.root.text, "-", chunk.root.dep_, "-", chunk.root.head.text)
# Out:
# Canadian pharmacies - pharmacies - nsubj - limiting
# how much medication - medication - nsubjpass - dispensed
# shortages - shortages - dobj - prevent
# most active ingredients - ingredients - nsubj - come
# drugs - drugs - pobj - for
# India - India - pobj - from
# China and medical supply chains - chains - conj - India
# the spread - spread - pobj - by
# COVID-19 - COVID-19 - pobj - of

# %%
# local tree
for token in doc:
    print(token.text, "-", token.dep_, "-", token.head.text, "-", token.head.pos_, "-", 
            [child for child in token.children])
# Out:
# Canadian - amod - pharmacies - NOUN - []
# pharmacies - nsubj - limiting - VERB - [Canadian]
# are - aux - limiting - VERB - []
# limiting - ROOT - limiting - VERB - [pharmacies, are, dispensed, disrupted]
# how - advmod - much - ADJ - []
# much - amod - medication - NOUN - [how]
# medication - nsubjpass - dispensed - VERB - [much]
# can - aux - dispensed - VERB - []
# be - auxpass - dispensed - VERB - []
# dispensed - ccomp - limiting - VERB - [medication, can, be, try]
# to - aux - try - VERB - []
# try - xcomp - dispensed - VERB - [to, prevent]
# to - aux - prevent - VERB - []
# prevent - xcomp - try - VERB - [to, shortages]
# shortages - dobj - prevent - VERB - [recognizing]
# recognizing - acl - shortages - NOUN - [come]
# that - mark - come - VERB - []
# most - advmod - active - ADJ - []
# active - amod - ingredients - NOUN - [most]
# ingredients - nsubj - come - VERB - [active, for]
# for - prep - ingredients - NOUN - [drugs]
# drugs - pobj - for - ADP - []
# come - ccomp - recognizing - VERB - [that, ingredients, from]
# from - prep - come - VERB - [India]
# India - pobj - from - ADP - [and, chains]
# and - cc - India - PROPN - []
# China - nmod - chains - NOUN - [and, supply]
# and - cc - China - PROPN - []
# medical - amod - supply - NOUN - []
# supply - conj - China - PROPN - [medical]
# chains - conj - India - PROPN - [China]
# have - aux - disrupted - VERB - []
# been - auxpass - disrupted - VERB - []
# disrupted - conj - limiting - VERB - [have, been, by]
# by - agent - disrupted - VERB - [spread]
# the - det - spread - NOUN - []
# spread - pobj - by - ADP - [the, of]
# of - prep - spread - NOUN - [COVID-19]
# COVID-19 - pobj - of - ADP - []

# %%
# important verb in the sentence
verbs = set()
for possible_subject in doc:
    if possible_subject.dep == nsubj and possible_subject.head.pos == VERB:
        verbs.add(possible_subject.head)
print(verbs)
# Out:
# {limiting, come}

# %%
# local tree with root 'limiting'
print(doc[3])
print([token.text for token in doc[3].lefts]) 
print([token.text for token in doc[3].rights])
# Out:
# limiting
# ['pharmacies', 'are']
# ['dispensed', 'disrupted']

# %%
root = [token for token in doc if token.head == token][0]
print(root)
subject = list(root.lefts)[0]
for descendant in subject.subtree:
    assert subject is descendant or subject.is_ancestor(descendant)
    print(descendant.text, "-", descendant.dep_, "-", descendant.n_lefts, "-", 
            descendant.n_rights, "-", 
            [ancestor.text for ancestor in descendant.ancestors])
# Out:
# limiting
# Canadian - amod - 0 - 0 - ['pharmacies', 'limiting']
# pharmacies - nsubj - 1 - 0 - ['limiting']

# %% [markdown]
# ### Finding Subject/Object

# %%
# on the verb STOP
stop = []
for index, row in covid_small.iterrows():
    text = ' '.join(row['tokenized_text'])
    doc = nlp(text)
    for chunk in doc.noun_chunks:
        subject = 0
        object_ = 0
        if chunk.root.head.text == 'stopped' or chunk.root.head.text == 'stop':
            if chunk.root.dep_ == 'nsubj':
                subject = chunk.root.text
            if chunk.root.dep_ == 'dobj':
                object_ = chunk.root.text
            if subject is not 0 or object_ is not 0:
                stop.append((subject, object_))
stop
# Out:
# [('workers', 0),
#  (0, 'people'),
#  ('hospitals', 0),
#  ('work', 0),
#  ('us', 0),
#  (0, 'WATCH'),
#  (0, 'spread'),
#  (0, 'spread'),
#  ('we', 0),
#  (0, 'pandemic'),
#  (0, 'them'),
#  (0, 'spread'),
#  ('he', 0),
#  ('he', 0)]

# %%
# on the verb SPREAD
spread = []
for index, row in covid_small.iterrows():
    text = ' '.join(row['tokenized_text'])
    doc = nlp(text)
    for chunk in doc.noun_chunks:
        subject = 0
        object_ = 0
        if chunk.root.head.text == 'spread' or chunk.root.head.text == 'spreaded':
            if chunk.root.dep_ == 'nsubj':
                subject = chunk.root.text
            if chunk.root.dep_ == 'dobj':
                object_ = chunk.root.text
            if subject is not 0 or object_ is not 0:
                spread.append((subject, object_))
spread
# Out:
# [('it', 0),
#  ('it', 0),
#  ('virus', 0),
#  ('SARS', 0),
#  ('virus', 0),
#  (0, 'load'),
#  ('who', 0),
#  (0, 'it'),
#  ('Community', 0),
#  ('virus', 0)]

# %% [markdown]
# On ther verbs 'stop' and 'spread', there doesn't seem to be a pair of both subject and object. There is either subject only or object only! This suggests that the news talk about these verbs in very broad sense!

# %% [markdown]
# # Distributional distances

# %%
def makeProbsArray(dfColumn, overlapDict):
    words = dfColumn.sum()
    countList = [0] * len(overlapDict)
    for word in words:
        try:
            countList[overlapDict[word]] += 1
        except KeyError:
            #The word is not common so we skip it
            pass
    countArray = np.array(countList)
    return countArray / countArray.sum()

# %%
def kl_divergence(X, Y):
    P = X.copy()
    Q = Y.copy()
    P.columns = ['P']
    Q.columns = ['Q']
    df = Q.join(P).fillna(0)
    p = df.iloc[:,1]
    q = df.iloc[:,0]
    D_kl = scipy.stats.entropy(p, q)
    return D_kl

from scipy.spatial import distance
def js_divergence(X, Y):
    P = X.copy()
    Q = Y.copy()
    P.columns = ['P']
    Q.columns = ['Q']
    df = Q.join(P).fillna(0)
    p = df.iloc[:,1]
    q = df.iloc[:,0]
    D_kl = distance.jensenshannon(p, q)
    return D_kl

def chi2_divergence(X,Y):
    P = X.copy()
    Q = Y.copy()
    P.columns = ['P']
    Q.columns = ['Q']
    df = Q.join(P).fillna(0)
    p = df.iloc[:,1]
    q = df.iloc[:,0]
    return scipy.stats.chisquare(p, q).statistic


def Divergence(corpus1, corpus2, difference="KL"):
    """Difference parameter can equal KL, Chi2, or Wass"""
    freqP = nltk.FreqDist(corpus1)
    P = pandas.DataFrame(list(freqP.values()), columns = ['frequency'], index = list(freqP.keys()))
    freqQ = nltk.FreqDist(corpus2)
    Q = pandas.DataFrame(list(freqQ.values()), columns = ['frequency'], index = list(freqQ.keys()))
    if difference == "KL":
        return kl_divergence(P, Q)
    elif difference == "Chi2":
        return chi2_divergence(P, Q)
    elif difference == "KS":
        try:
            return scipy.stats.ks_2samp(P['frequency'], Q['frequency']).statistic
        except:
            return scipy.stats.ks_2samp(P['frequency'], Q['frequency'])
    elif difference == "Wasserstein":
        try:
            return scipy.stats.wasserstein_distance(P['frequency'], Q['frequency'], u_weights=None, v_weights=None).statistic
        except:
            return scipy.stats.wasserstein_distance(P['frequency'], Q['frequency'], u_weights=None, v_weights=None)
    elif difference == "JS":
        return js_divergence(P, Q)

# %% [markdown]
# ## <span style="color:red">*Exercise 6*</span>
#
# <span style="color:red">Construct cells immediately below this that calculate the KL and $\chi^2$ divergences, and the KS and Wasserstein distances between four separate corpora, plot these with heatmaps, and then array them in two dimensions with multidimensional scaling as above. What does this reveal about relations between the corpora? Which analysis (and divergence or distribution) distinguishes the authors or documents better?

# %%
mar = covid_news[covid_news['mon'] == 3]
early = covid_news[covid_news['mon'] != 3]
jan = covid_news[covid_news['mon'] == 1]
feb = covid_news[covid_news['mon'] == 2]

# %%
marWords = set(mar['normalized_tokens'].sum())
earlyWords = set(early['normalized_tokens'].sum())
overlapWords = marWords & earlyWords
overlapWordsDict = {word: index for index, word in enumerate(overlapWords)}

# %%
print(overlapWords)
# Out:
# {'2:06', 'countryside', 'mobility', 'amid', 'match', 'chat', 'enrolment', 'burn', 'proponent', 'ting', 'mexico', 'changer', 'rampant', 'casa', 'biochemistry', 'zhejiang', 'relieved', 'daily', 'motion', 'jungle', 'operation', 'repurpose', 'davis', 'suburban', 'historical', 'barrack', 'underwear', 'predominantly', 'mainly', 'delegation', 'siu', 'imf', 'camp', 'harvey', 'ritual', 'rosati', 'slowly', 'charter', 'predictable', 'wait', 'iraq', 'arizona', 'financial', 'states', 'balcony', 'mistrust', 'ste', 'amount', 'brokerage', 'compromise', 'reign', 'manitoba/', 'consultant', 'humanity', 'regular', 'inconvenient', 'procedure', 'literally', 'unreasonable', 'osorio', 'classify', 'residential', 'expensive', 'beer', 'live', 'homelessness', 'fine', 'massive', 'retiree', 'controversial', 'scary', 'starbucks', 'longueuil', 'turmoil', 'characterize', 'spook', 'cepi', 'microbe', 'mortality', 'oil', 'isle', 'shoe', 'mirror', 'mike', 'positively', 'pray', 'tired', 'shrink', 'richardson', 'luggage', 'describe', 'judge', 'threat', 'candidate', 'compensation', 'aids', 'nearly', 'busy', 'counter', 'description', 'emotional', 'sit', 'week', 'consul', 'cameroon', 'cost', 'appeal', 'length', 'alex', 'timeframe', 'edit', 'unanimously', 'misconduct', 'vehemently', 'dunne', 'equally', 'peace', 'anthropologist', 'change', 'handle', 'site', 'properly', 'receipt', 'plight', 'pension', 'roam', 'academy', 'paddle', 'mercedes', 'scarborough', 'nigerian', 'manchester', 'high', 'amanda', 'italians', 'clemence', 'workplace', 'soil', 'virus', 'proportionate', 'covid19?src', 'brain', 'psychologist', 'mnuchin', 'uplifted', 'scrutiny', 'distinguish', 'shortfall', 'meredith', 'hampton', 'vera', 'u.s', 'guantanamo', 'laurie', 'hoc', 'widely', 'seal', 'inn', 'presumptive', 'license', 'philanthropic', 'sour', 'precisely', '63-year', 'laissez', 'phac', 'lgbtq', 'thank', 'invite', 'anyways', 'wilson', 'champion', 'basis', 'rachel', 'n.s', 'victory', 'young', 'sense', 'grade', 'healthy', 'july', 'phenomenon', 'ali', 'chartrand', 'india', 'bogoch', 'importance', 'similar', 'niagara', 'airlines', 'outfit', 'structure', 'access', 'apocalypse', 'malicious', 'cautious', 'impact', 'independent', 'onwards', 'swap', 'clinician', 'siren', 'asymptomatic', 'unit', 'québécois', 'freak', 'pipe', 'unwashed', 'dalla', 'millilitre', 'probe', 'johns', 'coronavirusno', 'announcement', 'trace', 'outside', 'boot', 'unexpectedly', 'shout', 'coronavirus', 'hover', 'reflection', 'market', 'photographer', 'business', 'adequate', 'meter', 'discuss', 'weyburn', 'removal', 'formal', 'detailed', 'africans', 'compel', 'amazon.com', 'deepen', 'department', 'committed', 'infective', 'southern', 'memo', '18-year', 'psychological', 'modest', 'chongqing', 'calm', 'win', 'liberia', 'rigorous', 'pascal', 'sidewalk', 'look', 'roundtable', 'evaluation', 'saeed', 'inconsistent', 'airports', 'motorist', 'independently', 'richard', 'hickey', 'write', 'alaa', 'bicycle', 'aikins', 'eighth', 'prepared', 'underground', 'warship', 'allan', 'guinea', 'resources', 'stranger', 'meagre', 'stress', 'kingston', 'christian', 'rabie', 'wide', 'substantially', 'bia', 'youtube', 'ecuadoran', 'govcanhealth?ref_src', 'lady', 'surprised', 'west', 'regrettably', 'fishermen', '66-year', 'campaign', 'competition', 'assessment', 'jersey', 'thinking', 'respect', 'appearance', 'melinda', 'strong', 'administration', 'verified', 'toll', 'lupton', 'pollutant', 'bernice', 'alive', 'deck', 'kyeong', 'grabher', 'wheat', 'wholly', 'unopened', 'citizens', 'postdoctoral', 'diplomat', 'avoidable', 'cycle', 'organize', 'light', 'condone', 'dissent', 'macky', 'harrowing', 'reassured', 'sway', 'nervousness', 'airlift', 'rona', 'codogno', 'tavern', 'statement', 'learn', 'spark', 'norovirus', 'untrue', 'brilliant', 'restart', 'twist', 'manitoban', 'independence', 'compensate', 'nicholas', 'twsrc%5etfw">#canada</a', 'appoint', 'bronze', 'think', 'burner', 'entice', 'attachment', 'enhance', 'graph', 'info', 'origin', '2nd', 'diabetic', 'neurologist',  ...

# %% [markdown]
# ### Before March vs in March

# %%
marProbArray = makeProbsArray(mar['normalized_tokens'], overlapWordsDict)
earlyProbArray = makeProbsArray(early['normalized_tokens'], overlapWordsDict)

# %%
mar_earlyDivergence = scipy.stats.entropy(marProbArray, earlyProbArray)
print (mar_earlyDivergence)
early_marDivergence = scipy.stats.entropy(earlyProbArray, marProbArray)
print (early_marDivergence)
# Out:
# 0.30277573858858203
# 0.34573513943886214

# %% [markdown]
# You can see the news before vs in March are moderately different.

# %%
mar_earlyDivergence_ew = scipy.special.kl_div(marProbArray, earlyProbArray)
kl_df = pandas.DataFrame(list(overlapWordsDict.keys()), columns = ['word'], index = list(overlapWordsDict.values()))
kl_df = kl_df.sort_index()
kl_df['elementwise divergence'] = mar_earlyDivergence_ew
kl_df.sort_values(by='elementwise divergence', ascending=False)[:10]
# Out:
#              word  elementwise divergence
# 7229     covid-19                0.011446
# 6357        china                0.009259
# 1429   distancing                0.005921
# 5123        wuhan                0.005079
# 219   coronavirus                0.004063
# 993       chinese                0.003573
# 3057        march                0.003045
# 1871   quarantine                0.002672
# 6467     outbreak                0.002274
# 8677      service                0.002041

# %% [markdown]
# This seems to correlate with what actually happened well. 'covid-19' was used more commonly around March. China and Wuhan were mentioned less in March than before March.

# %% [markdown]
# ### In Jan. vs In Feb.

# %%
janWords = set(jan['normalized_tokens'].sum())
febWords = set(jan['normalized_tokens'].sum())
overlapWords = janWords & febWords
overlapWordsDict = {word: index for index, word in enumerate(overlapWords)}

# %%
janProbArray = makeProbsArray(jan['normalized_tokens'], overlapWordsDict)
febProbArray = makeProbsArray(feb['normalized_tokens'], overlapWordsDict)

# %%
jan_febDivergence = scipy.stats.entropy(janProbArray, febProbArray)
print (jan_febDivergence)
feb_janDivergence = scipy.stats.entropy(febProbArray, janProbArray)
print (feb_janDivergence)
# Out:
# inf
# 0.27472254734852924

# %% [markdown]
# The difference between news in February and in January is not as big as between before March and in March. Suggesting that Canada's news start to perceive COVID-19 differently starting in March.

# %%
feb_janDivergence_ew = scipy.special.kl_div(febProbArray, janProbArray)
kl_df = pandas.DataFrame(list(overlapWordsDict.keys()), columns = ['word'], index = list(overlapWordsDict.values()))
kl_df = kl_df.sort_index()
kl_df['elementwise divergence'] = feb_janDivergence_ew
kl_df.sort_values(by='elementwise divergence', ascending=False)[:10]
# Out:
#             word  elementwise divergence
# 1330        ship                0.014192
# 5882      cruise                0.013383
# 1971    princess                0.007050
# 1621        iran                0.004389
# 4887    covid-19                0.004056
# 1273  quarantine                0.003955
# 5119       italy                0.002358
# 2722   passenger                0.002238
# 369         crew                0.002131
# 5692        sars                0.001908

# %% [markdown]
# Elementwise divergence here also matches the real situation well. Diamond Princess Cruise, Iran, and Italy got infected around February. SARS was probably dropped after January as COVID-19 itself became well-known by then.

# %% [markdown]
# ### 30 Earliest Articles

# %%
corpora = []
for index, row in early.iterrows():
    if len(corpora) > 30:
        break
    corpora.append(row['tokenized_text'])

# %%
corpora_s = []
corpora_nons = []
for corpus in corpora:
    s = []
    nons = []
    doc = nlp(' '.join(corpus))
    for word in doc:
        if word.is_stop:
            s.append(word.text)
        else:
            nons.append(word.text)
    corpora_s.append(s)
    corpora_nons.append(nons)

# %%
fileids = list(early['md'])[0:31]

# %%
index = [i for i in range(31)]

# %%
L = []
for p in corpora:
    l = []
    for q in corpora:
        l.append(Divergence(p,q, difference = 'KL'))
    L.append(l)
M = np.array(L)
mds = sklearn.manifold.MDS()
pos = mds.fit(M).embedding_
x = pos[:,0]
y = pos[:,1]
fig, ax = plt.subplots(figsize = (6,6))
plt.plot(x, y, ' ')
for i, txt in enumerate(fileids):
    ax.annotate(txt, (x[i],y[i]), size = 10)
# Out:
# /Users/wanitchaya.poon/opt/anaconda3/lib/python3.7/site-packages/sklearn/manifold/mds.py:421: UserWarning: The MDS API has changed. ``fit`` now constructs an dissimilarity matrix from data. To use a custom dissimilarity matrix, set ``dissimilarity='precomputed'``.
#   warnings.warn("The MDS API has changed. ``fit`` now constructs an"

# %% [markdown]
# Article on 2020-1-1 seems to be super different from the rest...? Below is probably why...

# %%
covid_news[covid_news['md'] == '2020-1-19']['title'].iloc[1]
# Out:
# "Here are Ottawa's photos of the week"

# %%
covid_news[covid_news['md'] == '2020-1-19']['text'].iloc[1]
# Out:
# 'As always, CBC Ottawa\'s reporters were out this past week capturing all the goings-on in the region. This week\xa0they met the young stars of a new awareness campaign, sat down with\xa0a group of men affected by the city\'s "housing emergency" and spoke to Ottawans with family trapped overseas by the coronavirus outbreak.\xa0 Here are some of the highlights: This week Ottawa became the first city in the country to declare a housing and homelessness emergency. Ed Campbell, 68, is moving to Prescott, Ont., to find somewhere to live.  (Matthew Kupfer/CBC ) \'Broke on payday\': Facing eviction, longtime tenants feeling Ottawa\'s housing squeeze firsthand City declares housing emergency Amelia Watson, 8, is part of an advertisement campaign on OC Transpo buses in Ottawa to raise awareness of Tourette Syndrome. (Laura Glowacki/CBC) Tourette campaign shows syndrome\'s younger face This was the first weekend of Winterlude. Snow sculptors were at work in Gatineau\'s Jacques-Cartier Park. (Ian Black/CBC) WeatherA pleasant weekend on the way as winter festivals begin Emily Chen uses messaging apps like WeChat to call her mother everyday. Chen\'s mother has been trapped inside a Wuhan apartment ever since the city went into lockdown.  (Joseph Tunney/CBC) Situation for Canadian trapped in Wuhan growing dire, says daughter Carleton student\'s twin still trapped by Chinese coronavirus lockdown Ottawa police\'s hate crime unit has charged a man in connection with the defacing of a Algonquin College mural featuring First Nations themes. Ron McLester, who also goes by the traditional name Deganadus, called the vandalism an "act of violence."  (Jean Delisle/CBC) Indigenous mural vandalized at Algonquin College Police arrest man in connection to defaced Indigenous mural '

# %%
L = []
for p in corpora_nons:
    l = []
    for q in corpora_nons:
        l.append(Divergence(p,q, difference='KL'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.xticks(index, fileids, size = 7)
plt.yticks(index, fileids, size = 7)
plt.show()

# %% [markdown]
# The differences are even clearer using `KL` on nonstopword corpus! However, the differences are not that clear using `Chi2`, `KS`, and `Wasserstein`.

# %%
L = []
for p in corpora:
    l = []
    for q in corpora:
        l.append(Divergence(p,q, difference='Chi2'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.xticks(index, fileids, size = 7)
plt.yticks(index, fileids, size = 7)
plt.show()

# %%
L = []
for p in corpora:
    l = []
    for q in corpora:
        l.append(Divergence(p,q, difference='KS'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.xticks(index, fileids, size = 7)
plt.yticks(index, fileids, size = 7)
plt.show()

# %%
L = []
for p in corpora:
    l = []
    for q in corpora:
        l.append(Divergence(p,q, difference='Wasserstein'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.xticks(index, fileids, size = 7)
plt.yticks(index, fileids, size = 7)
plt.show()

# %% [markdown]
# <span style="color:red">**Stretch**: Calculate the <a "href=https://en.wikipedia.org/wiki/Jensen–Shannon_divergence" target="_blank">Jensen-Shannon Divergence</a> between your four corpora. What is the relationship between the KL and JS divergences?</span>

# %%
L = []
for p in corpora_nons:
    l = []
    for q in corpora_nons:
        l.append(Divergence(p,q, difference='JS'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.xticks(index, fileids, size = 7)
plt.yticks(index, fileids, size = 7)
plt.show()

# %% [markdown]
# Using `JS` is really similar to using `KL`! However, the absolute size of the divergence using `JS` is smaller than using `KL`. So, it probably better to use `JS` when we want to distinguish at the very small detail. However, if we want to distinguish corpora at a more coarse level, `KL` might be better.
#
# ### 30 Latest Articles before March

# %%
corpora = []
for index, row in early[::-1].iterrows():
    if len(corpora) > 30:
        break
    corpora.append(row['tokenized_text'])

# %%
corpora_s = []
corpora_nons = []
for corpus in corpora:
    s = []
    nons = []
    doc = nlp(' '.join(corpus))
    for word in doc:
        if word.is_stop:
            s.append(word.text)
        else:
            nons.append(word.text)
    corpora_s.append(s)
    corpora_nons.append(nons)

# %%
fileids = list(early[::-1]['md'])[0:31]

# %%
index = [i for i in range(31)]

# %%
L = []
for p in corpora:
    l = []
    for q in corpora:
        l.append(Divergence(p,q, difference = 'KL'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.xticks(index, fileids, size = 7)
plt.yticks(index, fileids, size = 7)
plt.show()

# %%
L = []
for p in corpora_s:
    l = []
    for q in corpora_s:
        l.append(Divergence(p,q, difference='KL'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.xticks(index, fileids, size = 7)
plt.yticks(index, fileids, size = 7)
plt.show()

# %% [markdown]
# It is even clearer using `KL` on stopwords only.

# %%
mds = sklearn.manifold.MDS()
pos = mds.fit(M).embedding_
x = pos[:,0]
y = pos[:,1]
fig, ax = plt.subplots(figsize = (6,6))
plt.plot(x, y, ' ')
for i, txt in enumerate(fileids):
    ax.annotate(txt, (x[i],y[i]), size = 10)
# Out:
# /Users/wanitchaya.poon/opt/anaconda3/lib/python3.7/site-packages/sklearn/manifold/mds.py:421: UserWarning: The MDS API has changed. ``fit`` now constructs an dissimilarity matrix from data. To use a custom dissimilarity matrix, set ``dissimilarity='precomputed'``.
#   warnings.warn("The MDS API has changed. ``fit`` now constructs an"

# %% [markdown]
# Article on 2020-2-29 seems very different! The rest of the articles are very similar. Below is probably why...

# %%
early[::-1][:15].iloc[-1]['title']
# Out:
# 'While Winnipeg travellers worry about coronavirus, common illnesses are more likely to ruin a holiday'

# %%
early[::-1][:15].iloc[-1]['text']
# Out:
# "Public health is of greater concern during the annual\xa0influx of travellers at Winnipeg Richardson International Airport this year, owing to the international outbreak of novel coronavirus, known as COVID-19. However, the health risks are a lot less novel for most Manitobans going away this month. Traveller's diarrhea, diseases transmitted by insects and heat-related illnesses are much more common ailments for those headed to hot destinations.\xa0 Read more from the Winnipeg Free Press by clicking here. CBC Manitoba and the Winnipeg\xa0Free\xa0Press\xa0recognize each other as trusted news sources. This content is made available to our readers as part of a CBC Manitoba/ Winnipeg Free Press agreement to collaborate to better serve our community.\xa0 \xa0 \xa0 \xa0 \xa0 Any questions about\xa0Free\xa0Press\xa0content should be directed to:\xa0webnews@freepress.mb.ca."

# %%
L = []
for p in corpora_nons:
    l = []
    for q in corpora_nons:
        l.append(Divergence(p,q, difference='KL'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.xticks(index, fileids, size = 7)
plt.yticks(index, fileids, size = 7)
plt.show()

# %% [markdown]
# Using `KL` on non-stopword is not as useful. `Chi2`, `KS`, and `Wasserstein` aren't that useful too.

# %%
L = []
for p in corpora:
    l = []
    for q in corpora:
        l.append(Divergence(p,q, difference='Chi2'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.xticks(index, fileids, size = 7)
plt.yticks(index, fileids, size = 7)
plt.show()

# %%
L = []
for p in corpora:
    l = []
    for q in corpora:
        l.append(Divergence(p,q, difference='KS'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.xticks(index, fileids, size = 7)
plt.yticks(index, fileids, size = 7)
plt.show()

# %%
L = []
for p in corpora:
    l = []
    for q in corpora:
        l.append(Divergence(p,q, difference='Wasserstein'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.xticks(index, fileids, size = 7)
plt.yticks(index, fileids, size = 7)
plt.show()

# %% [markdown]
# <span style="color:red">**Stretch**: Calculate the <a "href=https://en.wikipedia.org/wiki/Jensen–Shannon_divergence" target="_blank">Jensen-Shannon Divergence</a> between your four corpora. What is the relationship between the KL and JS divergences?</span>

# %%
L = []
for p in corpora_s:
    l = []
    for q in corpora_s:
        l.append(Divergence(p,q, difference='JS'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.xticks(index, fileids, size = 7)
plt.yticks(index, fileids, size = 7)
plt.show()

# %% [markdown]
# Similar to the 30 earliest articles, `JS` is very similar to `KL`, only that `JS` takes on smaller absolute value.
